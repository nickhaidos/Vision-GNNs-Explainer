# %%
from utils import load_model_and_dict, visualize_gradient_incoming_edges

# %%
model, class_idx_to_name_map = load_model_and_dict("/content/weights/vig_s_80.6.pth", model_variant='vig_s_224_gelu', cls_to_labels_path="/content/imagenet1000_clsidx_to_labels.txt", device='auto')

# %%
# Early layer
visualize_gradient_incoming_edges(model, "/content/n03947888_pirate.jpg", layer=2, patch_coords=(7,8), imagenet_dict=class_idx_to_name_map, figsize=(6,6))
# Out:
# Predicted class:  pirate, pirate ship
# Patch (7,8) (green) [index 106]: 9 incoming (red, brighter have more similar embeddings)

# %%
# Mid layer
visualize_gradient_incoming_edges(model, "/content/n03947888_pirate.jpg", layer=7, patch_coords=(7,8), imagenet_dict=class_idx_to_name_map, figsize=(6,6))
# Out:
# Predicted class:  pirate, pirate ship
# Patch (7,8) (green) [index 106]: 12 incoming (red, brighter have more similar embeddings)

# %%
# Deep layer
visualize_gradient_incoming_edges(model, "/content/n03947888_pirate.jpg", layer=14, patch_coords=(7,8), imagenet_dict=class_idx_to_name_map, figsize=(6,6))
# Out:
# Predicted class:  pirate, pirate ship
# Patch (7,8) (green) [index 106]: 16 incoming (red, brighter have more similar embeddings)
